# %%
import pandas as pd
import numpy as np


df = pd.read_csv('F:/BA_Assigments/District_health_data_in_india.csv')
df.head()
# Out:
#             District Names                   State/UT  \
# 0                 Nicobars  Andaman & Nicobar Islands
# 1  North & Middle Andaman   Andaman & Nicobar Islands
# 2           South Andaman   Andaman & Nicobar Islands
# 3              Srikakulam              Andhra Pradesh
# 4            Vizianagaram              Andhra Pradesh
#
#    Number of Households surveyed  Number of Women age 15-49 years interviewed  \
# 0                            882                                          764
# 1                            874                                          789
# 2                            868                                          844
# 3                            874                                          780
# 4                            902                                          853
#
#    Number of Men age 15-54 years interviewed  \
# 0                                        125
# 1                                        108
# ...

# %%
df.columns
# Out:
# Index(['District Names', 'State/UT', 'Number of Households surveyed',
#        'Number of Women age 15-49 years interviewed',
#        'Number of Men age 15-54 years interviewed',
#        'Female population age 6 years and above who ever attended school (%)',
#        'Population below age 15 years (%)',
#        ' Sex ratio of the total population (females per 1,000 males)',
#        'Sex ratio at birth for children born in the last five years (females per 1,000 males)',
#        'Children under age 5 years whose birth was registered with the civil authority (%)',
#        ...
#        'Men age 15 years and above wih Mildly elevated blood pressure (Systolic 140-159 mm of Hg and/or Diastolic 90-99 mm of Hg) (%)',
#        'Men age 15 years and above wih Moderately or severely elevated blood pressure (Systolic ?160 mm of Hg and/or Diastolic ?100 mm of Hg) (%)',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Columns: 109 entries, District Names to Men age 15 years and above who consume alcohol (%)
# dtypes: float64(54), int64(4), object(51)
# memory usage: 602.2+ KB

# %%
df.columns.values.tolist()
# Out:
# ['District Names',
#  'State/UT',
#  'Number of Households surveyed',
#  'Number of Women age 15-49 years interviewed',
#  'Number of Men age 15-54 years interviewed',
#  'Female population age 6 years and above who ever attended school (%)',
#  'Population below age 15 years (%)',
#  ' Sex ratio of the total population (females per 1,000 males)',
#  'Sex ratio at birth for children born in the last five years (females per 1,000 males)',
#  'Children under age 5 years whose birth was registered with the civil authority (%)',
#  'Deaths in the last 3 years registered with the civil authority (%)',
#  'Population living in households with electricity (%)',
#  'Population living in households with an improved drinking-water source1 (%)',
#  'Population living in households that use an improved sanitation facility2 (%)',
#  'Households using clean fuel for cooking3 (%)',
#  'Households using iodized salt (%)',
# ...

# %%
df['State/UT'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli & Daman and Diu', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', ' Lakshadweep ', 'Madhya Pradesh',
#        'Maharastra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'NCT of Delhi', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
pd.set_option('display.max_rows', None)
state=df[['State/UT','District Names',' Sex ratio of the total population (females per 1,000 males)','Sex ratio at birth for children born in the last five years (females per 1,000 males)']]
state
# Out:
#                                    State/UT                 District Names  \
# 0                 Andaman & Nicobar Islands                       Nicobars
# 1                 Andaman & Nicobar Islands        North & Middle Andaman
# 2                 Andaman & Nicobar Islands                 South Andaman
# 3                            Andhra Pradesh                    Srikakulam
# 4                            Andhra Pradesh                  Vizianagaram
# 5                            Andhra Pradesh                 Visakhapatnam
# 6                            Andhra Pradesh                 East Godavari
# 7                            Andhra Pradesh                 West Godavari
# 8                            Andhra Pradesh                       Krishna
# 9                            Andhra Pradesh                        Guntur
# 10                           Andhra Pradesh                      Prakasam
# 11                           Andhra Pradesh     Sri Potti Sriramulu Nello
# ...

# %%
#pd.set_option('display.max_rows', None)
#state=df[['State/UT','District Names',' Sex ratio of the total population (females per 1,000 males)']]
#state.to_csv('sr.csv')

# %%
state
# Out:
#                                    State/UT                 District Names  \
# 0                 Andaman & Nicobar Islands                       Nicobars
# 1                 Andaman & Nicobar Islands        North & Middle Andaman
# 2                 Andaman & Nicobar Islands                 South Andaman
# 3                            Andhra Pradesh                    Srikakulam
# 4                            Andhra Pradesh                  Vizianagaram
# 5                            Andhra Pradesh                 Visakhapatnam
# 6                            Andhra Pradesh                 East Godavari
# 7                            Andhra Pradesh                 West Godavari
# 8                            Andhra Pradesh                       Krishna
# 9                            Andhra Pradesh                        Guntur
# 10                           Andhra Pradesh                      Prakasam
# 11                           Andhra Pradesh     Sri Potti Sriramulu Nello
# ...

# %%
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 4 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   State/UT                                                                               707 non-null    object
#  1   District Names                                                                         707 non-null    object
#  2    Sex ratio of the total population (females per 1,000 males)                           707 non-null    int64
#  3   Sex ratio at birth for children born in the last five years (females per 1,000 males)  707 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 22.2+ KB

# %%
state.isnull().sum()
# Out:
# State/UT                                                                                 0
# District Names                                                                           0
#  Sex ratio of the total population (females per 1,000 males)                             0
# Sex ratio at birth for children born in the last five years (females per 1,000 males)    0
# dtype: int64

# %%
g=state.groupby('State/UT')
g

# %%
#gm=g.get_group('Tamil Nadu')

# %%
#gm.mean()

# %%
sex_ratio=g.mean()

# %%
#sex_ratio.to_csv('F:/expe/sex_ratio_india.csv')

# %%
sex_ratio
# Out:
#                                          Sex ratio of the total population (females per 1,000 males)
# State/UT
#  Lakshadweep                                                                  1187.000000
# Andaman & Nicobar Islands                                                      963.333333
# Andhra Pradesh                                                                1051.307692
# Arunachal Pradesh                                                              990.300000
# Assam                                                                         1007.545455
# Bihar                                                                         1089.184211
# Chandigarh                                                                     917.000000
# Chhattisgarh                                                                  1024.962963
# Dadra and Nagar Haveli & Daman and Diu                                         968.000000
# ...

# %%
pd.set_option('display.max_rows', None)
sabc=df[['State/UT','Sex ratio at birth for children born in the last five years (females per 1,000 males)']]
sabc
# Out:
#                                    State/UT  \
# 0                 Andaman & Nicobar Islands
# 1                 Andaman & Nicobar Islands
# 2                 Andaman & Nicobar Islands
# 3                            Andhra Pradesh
# 4                            Andhra Pradesh
# 5                            Andhra Pradesh
# 6                            Andhra Pradesh
# 7                            Andhra Pradesh
# 8                            Andhra Pradesh
# 9                            Andhra Pradesh
# 10                           Andhra Pradesh
# 11                           Andhra Pradesh
# 12                           Andhra Pradesh
# 13                           Andhra Pradesh
# 14                           Andhra Pradesh
# 15                           Andhra Pradesh
# 16                        Arunachal Pradesh
# 17                        Arunachal Pradesh
# 18                        Arunachal Pradesh
# 19                        Arunachal Pradesh
# ...

# %%
sabc.dtypes
# Out:
# State/UT                                                                                 object
# Sex ratio at birth for children born in the last five years (females per 1,000 males)    object
# dtype: object

# %%
sabc.loc[323,'Sex ratio at birth for children born in the last five years (females per 1,000 males)']=1261
sabc.loc[330,'Sex ratio at birth for children born in the last five years (females per 1,000 males)']=1111
# Out:
# C:\Users\Sivashanmugavadivel\AppData\Local\Temp\ipykernel_16888\1692617716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sabc.loc[323,'Sex ratio at birth for children born in the last five years (females per 1,000 males)']=1261
# C:\Users\Sivashanmugavadivel\AppData\Local\Temp\ipykernel_16888\1692617716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sabc.loc[330,'Sex ratio at birth for children born in the last five years (females per 1,000 males)']=1111

# %%
sabc['Sex ratio at birth for children born in the last five years (females per 1,000 males)']=sabc['Sex ratio at birth for children born in the last five years (females per 1,000 males)'].astype(str).astype(float)
# Out:
# C:\Users\Sivashanmugavadivel\AppData\Local\Temp\ipykernel_16888\199872491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sabc['Sex ratio at birth for children born in the last five years (females per 1,000 males)']=sabc['Sex ratio at birth for children born in the last five years (females per 1,000 males)'].astype(str).astype(float)

# %%
sabc.dtypes
# Out:
# State/UT                                                                                  object
# Sex ratio at birth for children born in the last five years (females per 1,000 males)    float64
# dtype: object

# %%
gc=sabc.groupby('State/UT')
gc

# %%
sabc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 2 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   State/UT                                                                               707 non-null    object
#  1   Sex ratio at birth for children born in the last five years (females per 1,000 males)  707 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 11.2+ KB

# %%
gc.first()
# Out:
#                                         Sex ratio at birth for children born in the last five years (females per 1,000 males)
# State/UT
#  Lakshadweep                                                                       1051.0
# Andaman & Nicobar Islands                                                           927.0
# Andhra Pradesh                                                                     1163.0
# Arunachal Pradesh                                                                   834.0
# Assam                                                                              1003.0
# Bihar                                                                               904.0
# Chandigarh                                                                          838.0
# Chhattisgarh                                                                        864.0
# Dadra and Nagar Haveli & Daman and Diu                                              983.0
# ...

# %%
gc.mean()
# Out:
#                                         Sex ratio at birth for children born in the last five years (females per 1,000 males)
# State/UT
#  Lakshadweep                                                                  1051.000000
# Andaman & Nicobar Islands                                                      902.000000
# Andhra Pradesh                                                                 944.230769
# Arunachal Pradesh                                                              978.150000
# Assam                                                                          973.121212
# Bihar                                                                          926.842105
# Chandigarh                                                                     838.000000
# Chhattisgarh                                                                  1000.074074
# Dadra and Nagar Haveli & Daman and Diu                                         857.333333
# ...

# %%
df = pd.DataFrame({'strain': ['10.123456789', '10.23456789', '10.3456789'],
                   'temp': ['1.7', '1.8', '1.9'],
                   'weight': ['100.4', '100.5', '100.6'],
                  })

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   strain  3 non-null      object
#  1   temp    3 non-null      object
#  2   weight  3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
df['strain_float'] = df['strain'].astype(float).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   strain        3 non-null      object
#  1   temp          3 non-null      object
#  2   weight        3 non-null      object
#  3   strain_float  3 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 224.0+ bytes
